# %%
from querries import query_recipies, ingredient_similarity_search, get_recipy_by_ingredients
from data_formats import *

# %%
result : QueryResult = query_recipies("spinach noodles", mode="text", enforce_images=True)
print(result.hits[0].recipe.displayName)
result.hits[0].recipe.images[0].get_image().resize((224, 224))
# Out:
# Scallops with garlic and spinach rice noodles
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
result : QueryResult = query_recipies("bolognese lasagna", mode="vec", min_cos_sim=0.8, enforce_images=True)
print(result.hits[0].recipe.displayName)
result.hits[0].recipe.images[0].get_image().resize((224, 224))
# Out:
# Lasagna Bolognese for Two
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
result : QueryResult = query_recipies(size=100, max_total_minutes=5, enforce_images=True, max_steps=5)
print(result.n_hits)

recipe : Recipe = result.hits[0].recipe

print(recipe.displayName, "the cooking time: ", recipe.totalTimeMinutes, "number of steps: ", len(recipe.instructions))
recipe.images[0].get_image().resize((224, 224))

# %%
result : QueryResult = get_recipy_by_ingredients(["spinach","tomato", "egg plant"], max_total_minutes=200 ,enforce_images=True)
print(result.hits[0].recipe.displayName, result.hits[0].recipe.totalTimeMinutes)
result.hits[0].recipe.images[0].get_image().resize((224, 224))
# Out:
# Fire-Roasted Fieri Lasagna 170
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
res : List[Ingredient] = ingredient_similarity_search("fenchel")

[i.displayText for i in res]
# Out:
# ['1 teaspoon fennel, ground and toasted',
#  '1.0 Fennel Bulb',
#  '1.0 cup Fennel Bulb',
#  '½ tsp Fennel Bulb',
#  '2 medium fennel bulbs, trimmed, reserve some fronds']
